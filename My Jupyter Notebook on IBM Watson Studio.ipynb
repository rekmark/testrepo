# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Rebecca Ekmark__
# Presently a farmer, hopefully a data scientist

# %% [markdown]
# _I am interested in data science because of the diversity of the field and the potential to work in many different sectors of business, science, education, and government. I could explore information and render it useful in a field that I am potentially suited for._

# %% [markdown]
# ### equation 1+1

# %%
(1+1)
# Out:
# 2

# %% [markdown]
# - making
# - lists
# - is
# - fun

# %% [markdown]
# > In a hole in the ground there lived a hobbit

# %% [markdown]
# >> it was a hobbit hole and that means comfort

# %% [markdown]
# 1. Bilbo
# 2. Frodo
# 3. Samwise
# 4. Merry
# 5. Pippin

# %% [markdown]
# <del>the ring should have never gone to Mordor</del>
